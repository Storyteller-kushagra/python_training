# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = np.zeros((100,100,3) , dtype=np.uint8)

# %%
plt.imshow(img)

# %% [markdown]
# img

# %%
img[20:10, 20:20 , 1] = 255

# %%
plt.imshow(img)

# %%
import PIL  #to load image

# %%
pan = PIL.Image.open("../Lecture_1/image.jpg")

# %%
chacha = np.array(pan)

# %%
type(chacha)
# Out:
# numpy.ndarray

# %%
chacha.shape
# Out:
# (720, 1280, 3)

# %%
plt.imshow(pan)

# %%
f = open("myedit.jpg" , "wb")
pan.save(f)

# %%
chacha[:,:,0] = 0

# %%
plt.imshow(chacha)

# %%
short =  chacha[::]
