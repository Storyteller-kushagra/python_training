# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
cb_pil = PIL.Image.open("img.png")

# %%
cb_np = np.array(cb_pil)

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
plt.imshow(cb_np[ : , : , 3], cmap="gray")

# %%
panda_pil = PIL.Image.open("imagee.jpeg")

panda_np = np.array(panda_pil)

panda_np.shape

cut = panda_np[:cb_np.shape[0], -cb_np.shape[1]:]

# %%
plt.imshow(cb_np)

# %%
plt.imshow(panda_np)

# %%
plt.imshow(cut)

# %%
for row in range(cb_np.shape[0]):
    for col in range(cb_np.shape[1]):
        if(cb_np[row,col,3])>100:
            cut[row,col] = cb_np[row,col,:3]

# %%
plt.imshow(cut)

# %%
    plt.imshow(panda_np)

# %%
cb_np[40, 200, 3]
# Out:
# 0

# %%
img = PIL.Image.fromarray(panda_np)

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=500x355 at 0x7F5CDC5B9E80>
